# %%
import nltk
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from urllib.request import urlopen
from bs4 import BeautifulSoup
url = "https://tengrinews.kz/"
html = urlopen(url).read()
soup = BeautifulSoup(html)
print(soup)
# удалить все элементы скрипта и стиля
for script in soup(["script", "style"]):
    script.extract()    # извлечение данных
print(soup)

text = soup.get_text()
print(text)
# разбить линии и убрать начальные и конечные пробелы в каждой строке
lines = (line.strip() for line in text.splitlines())
# разбить несколько заголовков в строке каждый
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# пустые строки
text = 'n'.join(chunk for chunk in chunks if chunk)

print(text)
#скачать и распечатать стоп-слова для рус/каз языка
from nltk.corpus import stopwords
#nltk.download('stopwords')
stop_words = set(stopwords.words('russian','kazakh'))
print(stop_words)

#токенизировать набор данных
from nltk.tokenize import sent_tokenize, word_tokenize
words = word_tokenize(text)
print(words)

# удаляет знаки препинания и цифры
wordsFiltered = [word.lower() for word in words if word.isalpha()]
print(wordsFiltered)

# удалить стоп-слова из набора токенизированных данных
filtered_words = [word for word in wordsFiltered if word not in stopwords.words('russian','kazakh')]
print(filtered_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Alisher\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Alisher\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <!DOCTYPE html>
# <html lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="pGq9z9GbzuR8y7p9U8vMCm8Cs4RxB1K1QKfUxCjV" name="csrf-token"/>
# <link href="/img/search-tn.png" rel="shortcut icon" type="image/png"/>
# <title>Tengrinews.kz – главный новостной портал Казахстана</title>
# <meta content="tengrinews, новости казахстана, новости мира, новости алматы, новости спорта, казахстан" name="Keywords"/>
# <meta content="Tengrinews.kz - круглосуточно обновляемая лента новостей. Последние новости Казахстана, России и мира о бизнесе, экономике, происшествиях, спорте" name="Description"/>
# <link href="https://tengrinews.kz/" rel="canonical"/>
# <link href="https://tengrinews.kz/amp/" rel="amphtml"/>
# <script>
#         var _url = location.href;
#         window.pushData = {
#             page_url: _url,
#             page_url_canonical: "http://tengrinews.kz/",
#             page_title: document.title,
#             page_type: "main",
#             page_language: 'ru',
#         };
#
#         window._io_config = window._io_config || {};
#         window._io_config['0.2.0'] = window._io_config['0.2.0'] || [];
#         window._io_config['0.2.0'].push(window.pushData);
#     </script>
# <link href="/css/core-fonts.css?v=167" rel="stylesheet"/>
# <link href="/css/core.css?v=167" rel="stylesheet"/>
# <link href="/css/banner.css?v=167" rel="stylesheet"/>
# <link href="/css/branding.css?v=167" rel="stylesheet"/>
# <script async="" src="https://yastatic.net/pcode/adfox/header-bidding.js"></script>
# <script>
#         var adfoxBiddersMap = {
#             "adfox_dsail-Minsk": "1210819"
#         };
#         var adUnits = [
#             {
#                 "codeType": "inpage",
#                 "code": "adfox_15640321474266268",
#                 "bids": [
#                     {
#                         "bidder": "adfox_dsail-Minsk",
#                         "params": {
#                             "p1": "chxiv",
#                             "p2": "foun",
#                             "puid1": "",
#                             "slide": true,
#                             "visibleAfterInit": true,
#                             "insertAfter": "undefined",
#                             "insertPosition": "0",
#                             "stick": false,
#                             "stickTo": "auto",
#                             "stickyColorScheme": "light"
#                         }
#                     }
#                 ]
#             }
#         ];
#         var userTimeout = 500;
#         window.YaHeaderBiddingSettings = {
#             biddersMap: adfoxBiddersMap,
#             adUnits: adUnits,
#             timeout: userTimeout
#         };
#     </script>
# <script>
#         (function () {
#             let them_switcher = [];
#             window.ChangeTheme = function () {
#                 let theme = localStorage.getItem('theme');
#                 let root = document.querySelector('html');
#                 let img = document.querySelectorAll('.tn-logo img');
#
#
#                 if (theme === 'dark') {
#
#                     root.style.setProperty('--background', '#171717');
#                     root.style.setProperty('--background_secondary', '#000000');
#                     root.style.setProperty('--white', '#2C2C2C');
#                     root.style.setProperty('--gray', '#FDFDFD ');
#                     root.style.setProperty('--gray_1', '#FDFDFD ');
#                     root.style.setProperty('--font-white', '#FFFFFF');
#                     root.style.setProperty('--font-black', '#FFFFFF');
#                     root.style.setProperty('--gray_2', '#8B8B8B');
#                     root.style.setProperty('--gray_3', '#8B8B8B');
#                     root.style.setProperty('--gray_8', 'rgba(212, 212, 212, 0.5)');
#                     root.style.setProperty('--tape-tn-data-list', '#575757');
#                     root.style.setProperty('--white_4', '#171717');
#                     root.style.setProperty('--black', '#FFFFFF');
#                     root.style.setProperty('--black_1', '#FFFFFF');
#                     root.style.setProperty('--black_2', 'rgba(255,255,255,0.1)');
#                     root.style.setProperty('--black_5', 'rgba(255,255,255,0.2)');
#                     root.style.setProperty('--black_6', 'rgba(255,255,255,0.6)');
#                     root.style.setProperty('--yellow', '#634903');
#                     root.style.setProperty('--mix-tag-color', '#FFFFFF');
#                     root.style.setProperty('--white_5', 'var(--white)');
#                     root.style.setProperty('--check-color', '#525252');
#                     root.style.setProperty('--mix-tn-data-list', 'rgba(255, 255, 255, 0.4)');
#
#                     root.style.setProperty('--tn-icon-vk', "url('/img/vk-light.svg')");
#                     root.style.setProperty('--tn-icon-fb', "url('/img/fb-light.svg')");
#                     root.style.setProperty('--tn-icon-tw', "url('/img/tw-light.svg')");
#                     root.style.setProperty('--tn-icon-instagram', "url('/img/instagram-light.svg')");
#                     root.style.setProperty('--tn-icon-mail', "url('/img/mail-light.svg')");
#                     root.style.setProperty('--tn-icon-ok', "url('/img/ok-light.svg')");
#                     root.style.setProperty('--tn-icon-tg', "url('/img/tg-light.svg')");
#                     root.style.setProperty('--mix-eye', "url('/img/eye-light.svg')");
#                     root.style.setProperty('--mix-comment', "url('/img/comment-light.svg')");
#                     root.style.setProperty('--eye', "url('/img/eye-light_1.svg')");
#                     root.style.setProperty('--comment', "url('/img/comment-light_1.svg')");
#                     root.style.setProperty('--arrow-down-dark', "url('/img/Vector_6.svg')");
#                     root.style.setProperty('--select-arrow', "url('/img/select-arrow-light.svg')");
#                     root.style.setProperty('--icon-menu', "url('/img/menu-light.svg')");
#                     root.style.setProperty('--icon-menu-close', "url('/img/icon-close-light.svg')");
#                     root.style.setProperty('--search-icon', "url('/img/search-light.svg')");
#
#
#                     img.forEach(function (i) {
#                         i.src = '/img/tn-logo-dark.png';
#                     });
#
#                 } else {
#
#                     root.style.setProperty('--background', '#f2f4f5');
#                     root.style.setProperty('--background_secondary', '#757575');
#                     root.style.setProperty('--white', '#ffffff');
#                     root.style.setProperty('--gray', '#2f2f2f');
#                     root.style.setProperty('--gray_1', '#2b2b2b');
#                     root.style.setProperty('--font-white', '#FFFFFF');
#                     root.style.setProperty('--font-black', '#000000');
#                     root.style.setProperty('--gray_2', '#575757');
#                     root.style.setProperty('--gray_3', '#757575');
#                     root.style.setProperty('--gray_8', 'rgba(43, 43, 43, 0.5)');
#                     root.style.setProperty('--tape-tn-data-list', '#575757');
#                     root.style.setProperty('--white_4', '#dfecdd');
#                     root.style.setProperty('--black', '#000000');
#                     root.style.setProperty('--black_1', '#1b1b1b');
#                     root.style.setProperty('--black_5', 'rgba(0,0,0,0.2)');
#                     root.style.setProperty('--yellow', '#fbca4a');
#                     root.style.setProperty('--mix-tag-color', 'var(--gray_4)');
#                     root.style.setProperty('--white_5', '#eaeaeb');
#                     root.style.setProperty('--check-color', '#FFFFFF');
#                     root.style.setProperty('--mix-tn-data-list', '#575757');
#                     root.style.setProperty('--black_2', 'rgba(0,0,0,0.1)');
#                     root.style.setProperty('--black_6', 'rgba(0,0,0,0.6)');
#
#                     root.style.setProperty('--tn-icon-vk', "url('/img/vk.svg')");
#                     root.style.setProperty('--tn-icon-fb', "url('/img/fb.svg')");
#                     root.style.setProperty('--tn-icon-tw', "url('/img/tw.svg')");
#                     root.style.setProperty('--tn-icon-instagram', "url('/img/instagram.svg')");
#                     root.style.setProperty('--tn-icon-mail', "url('/img/mail.svg')");
#                     root.style.setProperty('--tn-icon-ok', "url('/img/ok.svg')");
#                     root.style.setProperty('--tn-icon-tg', "url('/img/tg.svg')");
#                     root.style.setProperty('--mix-eye', "url('/img/eye-dark.svg')");
#                     root.style.setProperty('--mix-comment', "url('/img/comment-dark.svg')");
#                     root.style.setProperty('--eye', "url('/img/eye-dark.svg')");
#                     root.style.setProperty('--comment', "url('/img/comment-dark.svg')");
#                     root.style.setProperty('--arrow-down-dark', "url('/img/Vector_5.svg')");
#                     root.style.setProperty('--select-arrow', "url('/img/select-arrow.svg')");
#                     root.style.setProperty('--icon-menu', "url('/img/menu.svg')");
#                     root.style.setProperty('--icon-menu-close', "url('/img/icon-close.svg')");
#                     root.style.setProperty('--search-icon', "url('/img/search.svg')");
#
#
#                     img.forEach(function (i) {
#                         i.src = '/img/tn-logo.png';
#                     });
#
#                 }
#             };
#             window.ChangeTheme();
#             setTimeout(()=>{
#                 window.ChangeTheme();
#             },100);
#             window.addEventListener('load', function () {
#                 them_switcher = document.querySelectorAll('[tn-switch-them]');
#
#                 let theme = localStorage.getItem('theme');
#                 them_switcher.forEach(function (light_dark) {
#                     if (theme === 'dark') {
#                         light_dark.checked = true;
#                     } else {
#                         light_dark.checked = false;
#                     }
#                 });
#
#                 them_switcher.forEach(function (i) {
#                     i.addEventListener('click', function () {
#                         let theme = localStorage.getItem('theme');
#                         if (theme === 'dark') {
#                             localStorage.setItem('theme', 'light');
#                         } else {
#                             localStorage.setItem('theme', 'dark');
#                         }
#                         window.ChangeTheme();
#                     });
#                 });
#             });
#
#
#         })();
#     </script>
# </head>
# <body>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-MX5M2R" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script>(function (w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({
#             'gtm.start': new Date().getTime(), event: 'gtm.js'
#         });
#         var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.async = true;
#         j.src =
#             '//www.googletagmanager.com/gtm.js?id=' + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-MX5M2R');</script>
# <!-- End Google Tag Manager -->
# <div id="top"></div>
# <div class="my-app">
# <header>
# <nav class="tn-container tn-visible@t">
# <div class="tn-menu-fixed">
# <div class="tn-nav-item tn-background-secondary">
# <div class="tn-nav-flip-left">
# <ul class="tn-special-project-list">
# <li><a href="https://mix.tn.kz/" target="_blank">TengriMix</a></li>
# <li><a href="https://tengrinews.kz/tv/" target="_blank">TengriTV</a></li>
# <li><a href="https://tengritravel.kz/" target="_blank">TengriTravel</a></li>
# <li><a href="https://tengrinews.kz/pobediteli/" target="_blank">Победители</a></li>
# <li><a href="https://tengrinews.kz/zakon/" target="_blank">Законы Казахстана</a>
# </li>
# </ul>
# </div>
# <div class="tn-nav-flip-right">
# <ul class="tn-course-list">
# <li class="tn-course-list-header">
#         Курс валют
#     </li>
# <li>
# <span>
# <i class="tn-icon-dollar-white tn-hidden@m"></i>
# <i class="tn-icon-dollar tn-visible@m"></i>
#                 376.4
#                                 <i class="tn-icon-arrow-up-green"></i> </span>
# </li>
# <li>
# <span>
# <i class="tn-icon-euro-white tn-hidden@m"></i>
# <i class="tn-icon-euro tn-visible@m"></i>
#                 409.56
#                 <i class="tn-icon-arrow-down-red"></i> </span>
# </li>
# <li>
# <span>
# <i class="tn-icon-ruble-white tn-hidden@m"></i>
# <i class="tn-icon-ruble tn-visible@m"></i>
#                 5.91
#                 <i class="tn-icon-arrow-down-red"></i> </span>
# </li>
# </ul> </div>
# </div>
# <div class="tn-nav-item">
# <a class="tn-logo" href="/"><img alt="TengriNews.kz" src="/img/tn-logo.png"/></a>
# <div class="tn-adult-block"></div>
# <ul class="tn-type-materials">
# <li class=""><a href="/find-out/">Узнай</a></li>
# <li class=""><a href="/read/">Почитай</a>
# </li>
# <li class=""><a href="/take-look/">Посмотри</a></li>
# </ul>
# <div class="tn-language-switcher">
# <a href="//kaz.tengrinews.kz/">Қазақша</a>
# </div>
# <span class="tn-icon-search" tn-toggle-search=""></span>
# <a class="tn-subscribe-whatsapp" href="https://api.whatsapp.com/send?phone=77770014499&amp;text=%20">
#                     ПРИСЫЛАЙТЕ СВОИ НОВОСТИ НАМ
#                     <span>
#                 WhatsApp +7 (777) 001 44 99
#                 </span>
# </a>
# </div>
# <div class="tn-search-menu" tn-search-menu="">
# <div class="tn-inline tn-input-search">
# <span class="tn-icon-search"></span>
# <input tn-search-text="" type="search"/>
# <div class="tn-flip-left">
# <span class="tn-icon-clear" tn-clear-search=""></span>
# <div class="tn-button tn-button-default" tn-search-submit="">Искать</div>
# </div>
# </div>
# </div>
# <div class="tn-urgent-news">
# <div class="tn-urgent-news-title">Срочная новость</div>
# <div class="tn-urgent-news-message">Провал дороги у Сайрана в Алматы: причину назовет экспертиза</div>
# <a class="tn-urgent-news-button" href="#">Посмотреть </a>
# </div>
# </div>
# </nav>
# <nav class="tn-container tn-menu-mobile tn-hidden@t">
# <div class="tn-top-menu">
# <div class="tn-top-menu-container">
# <a class="tn-logo" href="/"><img alt="TengriNews.kz" src="/img/tn-logo.png"/></a>
# <div class="tn-adult-block"></div>
# <span class="tn-menu-mobile-button">
# <i class="tn-icon-menu">
# <svg fill="none" height="16" viewbox="0 0 24 16" width="24" xmlns="http://www.w3.org/2000/svg">
# <rect fill="var(--black)" height="2" width="24"></rect>
# <rect fill="var(--black)" height="2" width="24" y="7"></rect>
# <rect fill="var(--black)" height="2" width="24" y="14"></rect>
# </svg>
# </i>
# <i class="tn-icon-menu-close">
# <svg fill="none" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
# <rect fill="var(--black)" height="2" transform="rotate(45 2.2218 0.807617)" width="24" x="2.2218" y="0.807617"></rect>
# <rect fill="var(--black)" height="2" transform="rotate(-45 0.807617 17.7781)" width="24" x="0.807617" y="17.7781"></rect>
# </svg>
# </i>
# </span>
# </div>
# <div class="tn-type-materials-container">
# <ul class="tn-type-materials">
# <li class=""><a href="/find-out/">Узнай</a></li>
# <li class=""><a href="/read/">Почитай</a>
# </li>
# <li class=""><a href="/take-look/">Посмотри</a></li>
# </ul>
# <div class="tablet-menu-widget">
# <tn-weather-component></tn-weather-component>
# <div class="tn-language-switcher">
# <a href="//kaz.tengrinews.kz/">Қазақша</a>
# </div>
# <span class="tn-icon-search" tn-toggle-search=""></span>
# </div>
# </div>
# </div>
# </nav>
# <div class="tn-offcanvas-bar" id="tn-mobile-menu">
# <div class="tn-container">
# <div class="tn-inline tn-search-input">
# <i class="tn-icon-search"></i>
# <input placeholder="Поиск" tn-search-text="" type="text"/>
# <div class="onoffswitch" id="tn-theme-mobile" style="display: inline-block;">
# <input checked="" class="onoffswitch-checkbox" id="tn-theme-mobile-ch" name="tn-theme" tn-switch-them="" type="checkbox"/>
# <label class="onoffswitch-label" for="tn-theme-mobile-ch"></label>
# </div>
# </div>
# <ul class="tn-nav tn-nav-default tn-nav-parent-icon">
# <li class="tn-parent">
# <span>Спецпроекты</span>
# <ul class="tn-nav-sub">
# <li><a href="https://mix.tn.kz/" target="_blank">TengriMix</a></li>
# <li><a href="https://tengrinews.kz/tv/" target="_blank">TengriTV</a></li>
# <li><a href="https://tengritravel.kz/" target="_blank">TengriTravel</a></li>
# <li><a href="https://tengrinews.kz/pobediteli/" target="_blank">Победители</a></li>
# <li><a href="https://tengrinews.kz/zakon/" target="_blank">Законы Казахстана</a>
# </li>
# </ul>
# </li>
# <li class="tn-parent">
# <span>Прогноз погоды</span>
# </li>
# <li class="tn-parent">
# <ul class="tn-course-list">
# <li class="tn-course-list-header">
#         Курс валют
#     </li>
# <li>
# <span>
# <i class="tn-icon-dollar-white tn-hidden@m"></i>
# <i class="tn-icon-dollar tn-visible@m"></i>
#                 376.4
#                                 <i class="tn-icon-arrow-up-green"></i> </span>
# </li>
# <li>
# <span>
# <i class="tn-icon-euro-white tn-hidden@m"></i>
# <i class="tn-icon-euro tn-visible@m"></i>
#                 409.56
#                 <i class="tn-icon-arrow-down-red"></i> </span>
# </li>
# <li>
# <span>
# <i class="tn-icon-ruble-white tn-hidden@m"></i>
# <i class="tn-icon-ruble tn-visible@m"></i>
#                 5.91
#                 <i class="tn-icon-arrow-down-red"></i> </span>
# </li>
# </ul> </li>
# <li>
# <a class="tn-language-switch-button" href="https://kaz.tengrinews.kz/">Қазақша</a>
# </li>
# <li>
# <a class="tn-subscribe-whatsapp" href="https://api.whatsapp.com/send?phone=77770014499&amp;text=%20">
#                         ПРИСЫЛАЙТЕ СВОИ НОВОСТИ НАМ
#                         <span>
#                 WhatsApp +7 (777) 001 44 99
#                 </span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </header>
# <div class="tn-sub-container">
# <tn-top-banner-component></tn-top-banner-component>
# </div> <main>
# <h1 class="tn-hidden">
#         Tengrinews.kz – главный новостной портал Казахстана
#     </h1>
# <section class="tn-main-section tn-container">
# <div class="tn-main-news-container tn-sub-container">
# <div class="tn-main-news-grid">
# <div class="tn-main-news-item firs-column tn-three-column tn-background-cover" style="background:linear-gradient(360deg, #000000 0%, rgba(0, 0, 0, 0) 50%), url('/userdata/news/2020/news_391491/thumb_xs/photo_308408.jpeg') no-repeat center center/cover">
# <span class="tn-main-news-title">Казахстанцы оказались запертыми с зараженными коронавирусом на круизном лайнере</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>вчера, 16:21</time>
# </span>
# </li>
# <li>
# <view-show-component :id="'391491'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li><span><i class="tn-icon-comment"></i>74</span></li>
# </ul>
# <a class="tn-link" href="/kazakhstan_news/kazahstantsyi-okazalis-zapertyimi-zarajennyimi-koronavirusom-391491/"><span class="tn-hidden">Казахстанцы оказались запертыми с зараженными коронавирусом на круизном лайнере</span></a>
# </div>
# <div class="tn-main-news-item">
# <div class="tn-image-container">
# <img alt="© ktk.kz" src="/userdata/news/2020/news_391524/thumb_xms/photo_308451.png"/>
# </div>
# <span class="tn-main-news-title">Артисты театра Ауэзова отказываются выходить на сцену</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>сегодня, 01:04</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391524'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>2</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/kazakhstan_news/artistyi-teatra-auezova-otkazyivayutsya-vyihodit-na-stsenu-391524/"><span class="tn-hidden">Казахстанцы оказались запертыми с зараженными коронавирусом на круизном лайнере</span></a>
# </div>
# <div class="tn-main-news-item">
# <div class="tn-image-container">
# <img alt="© Reuters" src="/userdata/news/2020/news_391519/thumb_xms/photo_308445.jpeg"/>
# </div>
# <span class="tn-main-news-title">Коронавирус может поразить 60 процентов населения Земли</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>вчера, 21:35</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391519'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>51</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/medicine/koronavirus-mojet-porazit-60-protsentov-naseleniya-zemli-391519/"><span class="tn-hidden">Казахстанцы оказались запертыми с зараженными коронавирусом на круизном лайнере</span></a>
# </div>
# <div class="tn-main-news-item">
# <div class="tn-image-container">
# <img alt="Фото Aisultan Rakhat/Facebook" src="/userdata/news/2020/news_391515/thumb_xms/photo_308441.jpeg"/>
# </div>
# <span class="tn-main-news-title">Даурен Абаев прокомментировал посты Айсултана Рахата</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>вчера, 21:03</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391515'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>51</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/kazakhstan_news/dauren-abaev-prokommentiroval-postyi-aysultana-rahata-391515/"><span class="tn-hidden">Казахстанцы оказались запертыми с зараженными коронавирусом на круизном лайнере</span></a>
# </div>
# <div class="tn-main-news-item">
# <div class="tn-image-container">
# <img alt="Кадры из видео" src="/userdata/news/2020/news_391509/thumb_xms/photo_308431.png"/>
# </div>
# <span class="tn-main-news-title">Три массовых ДТП произошло на трассах в Казахстане</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>вчера, 19:09</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391509'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>13</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/kazakhstan_news/tri-massovyih-dtp-proizoshlo-na-trassah-v-kazahstane-391509/"><span class="tn-hidden">Казахстанцы оказались запертыми с зараженными коронавирусом на круизном лайнере</span></a>
# </div>
# <div class="tn-main-news-item">
# <div class="tn-image-container">
# <img alt="Фото:akorda.kz" src="/userdata/news/2020/news_391510/thumb_xms/photo_308432.jpeg"/>
# </div>
# <span class="tn-main-news-title">Токаев потребовал жестко пресекать провокации</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>вчера, 18:56</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391510'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>35</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/kazakhstan_news/tokaev-potreboval-jestko-presekat-provokatsii-391510/"><span class="tn-hidden">Казахстанцы оказались запертыми с зараженными коронавирусом на круизном лайнере</span></a>
# </div>
# <div class="tn-main-news-item">
# <div class="tn-image-container">
# <img alt="" src="/userdata/news/2020/news_391494/thumb_xms/photo_308413.png"/>
# </div>
# <span class="tn-main-news-title">Дело о смерти сына Кудебаева: адвокат врача пожаловался на затягивание расследования</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>вчера, 18:20</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391494'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>19</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/kazakhstan_news/delo-smerti-syina-kudebaeva-advokat-vracha-pojalovalsya-391494/"><span class="tn-hidden">Казахстанцы оказались запертыми с зараженными коронавирусом на круизном лайнере</span></a>
# </div>
# </div>
# <div class="tn-tape-container">
# <div class="tn-main-news-item banner">
# <tn-left-240x400-1-component :id="'main'"></tn-left-240x400-1-component>
# </div>
# <tn-tape-component></tn-tape-component>
# </div>
# </div>
# </section> <div class="tn-container">
# <div class="tn-after-main-banner">
# </div>
# </div>
# <section class="tn-read-section tn-container">
# <div class="tn-stn-find-out tn-section-header">
# <a class="tn-section-title" href="/read/">Почитай</a>
# <ul class="tn-tag-list">
# <li><a href="/conference/">Интервью</a></li>
# <li><a href="/article/">Статьи</a></li>
# <li><a href="/opinion/">Блоги и мнения</a></li>
# <li><a href="/tech/">Технологии</a></li>
# <li><a href="/science/">Наука</a></li>
# <li><a href="/tag/Мавритания">Мавритания</a></li>
# <li><a href="/tag/могул">могул</a></li>
# </ul>
# </div>
# <div class="tn-article-grid">
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="" src="/userdata/opinion/2020/opinion_989/thumb_xms/photo_922.jpeg"/>
# </div>
# <span class="tn-article-title">О первой женщине страны</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>12 февраля 2020, 14:20</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'989'" :lang="'ru'" :type="'opinion'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>8</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/opinion/o-pervoy-jenschine-stranyi-989/">
# <span class="tn-hidden">О первой женщине страны</span>
# </a>
# </div>
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="" src="/userdata/opinion/2020/opinion_988/thumb_xms/photo_921.jpeg"/>
# </div>
# <span class="tn-article-title">"Государство никогда так не беспокоилось о моем здоровье, как после возвращения из Китая"</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>11 февраля 2020, 14:25</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'988'" :lang="'ru'" :type="'opinion'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>9</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/opinion/gosudarstvo-tak-bespokoilos-moem-zdorove-posle-988/">
# <span class="tn-hidden">"Государство никогда так не беспокоилось о моем здоровье, как после возвращения из Китая"</span>
# </a>
# </div>
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="" src="/userdata/opinion/2020/opinion_987/thumb_xms/photo_920.jpeg"/>
# </div>
# <span class="tn-article-title">Про Кордай и все, что с ним связано</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>10 февраля 2020, 12:05</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'987'" :lang="'ru'" :type="'opinion'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>80</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/opinion/pro-korday-i-vse-chto-s-nim-svyazano-987/">
# <span class="tn-hidden">Про Кордай и все, что с ним связано</span>
# </a>
# </div>
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="" src="/userdata/opinion/2020/opinion_986/thumb_xms/photo_919.jpeg"/>
# </div>
# <span class="tn-article-title">Каких животных казахи не использовали в хозяйстве. Об обычае бәсіре</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>07 февраля 2020, 15:34</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'986'" :lang="'ru'" :type="'opinion'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>9</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/opinion/kakih-jivotnyih-kazahi-ispolzovali-hozyaystve-obyichae-basre-986/">
# <span class="tn-hidden">Каких животных казахи не использовали в хозяйстве. Об обычае бәсіре</span>
# </a>
# </div>
# </div>
# </section>
# <section class="tn-find-out tn-container tn-visible@t">
# <div class="tn-section-header">
# <a class="tn-section-title" href="/find-out/">Узнай</a>
# <ul class="tn-tag-list">
# <li><a href="/kazakhstan_news/">Новости Казахстана</a></li>
# <li><a href="/world_news/">Новости Мира</a></li>
# <li><a href="/accidents/">Проишествия</a></li>
# <li><a href="/sports/">Спорт</a></li>
# <li><a href="/tag/Добыча">Добыча</a></li>
# <li><a href="/tag/реабилитация">реабилитация</a></li>
# </ul>
# </div>
# <div class="tn-article-grid">
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="Кадры видео" src="/userdata/news/2020/news_391517/thumb_xms/photo_308443.jpeg"/>
# </div>
# <span class="tn-article-title">"Вези, тварь! Люди ждут". Пассажирка устроила истерику в такси</span>
# <ul class="tn-data-list">
# <li>
# <span>вчера, 20:46</span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391517'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>49</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/story/vezi-tvar-lyudi-jdut-passajirka-ustroila-isteriku-v-taksi-391517/">
# <span class="tn-hidden">"Вези, тварь! Люди ждут". Пассажирка устроила истерику в такси</span>
# </a>
# </div>
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="© Dynamo Moscow FC" src="/userdata/news/2020/news_391522/thumb_xms/photo_308449.png"/>
# </div>
# <span class="tn-article-title">Массовую потасовку затеяли футболисты "Кайрата" и "Динамо"</span>
# <ul class="tn-data-list">
# <li>
# <span>вчера, 23:32</span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391522'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>6</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/football/massovuyu-potasovku-zateyali-futbolistyi-kayrata-i-dinamo-391522/">
# <span class="tn-hidden">Массовую потасовку затеяли футболисты "Кайрата" и "Динамо"</span>
# </a>
# </div>
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="© fontanka.ru" src="/userdata/news/2020/news_391521/thumb_xms/photo_308448.jpeg"/>
# </div>
# <span class="tn-article-title">Боярский отказался комментировать нарушение: "Как вы все надоели"</span>
# <ul class="tn-data-list">
# <li>
# <span>вчера, 22:59</span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391521'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>14</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/cinema/boyarskiy-otkazalsya-kommentirovat-narushenie-kak-vse-391521/">
# <span class="tn-hidden">Боярский отказался комментировать нарушение: "Как вы все надоели"</span>
# </a>
# </div>
# <div class="tn-article-item">
# <div class="tn-left-240x150-1-banner"></div>
# </div>
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="Новый vivo V17 поможет принести радость любимому человеку" src="/userdata/news/2020/news_390860/thumb_xms/photo_307661.jpeg"/>
# </div>
# <span class="tn-article-title">Новый vivo V17 поможет принести радость любимому человеку</span>
# <ul class="tn-data-list">
# <li>
# <span>10 февраля 2020, 09:00</span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'390860'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# </ul>
# <a class="tn-link" href="/gadgets/novyiy-vivo-v17-pomojet-prinesti-radost-lyubimomu-cheloveku-390860/">
# <span class="tn-hidden">Новый vivo V17 поможет принести радость любимому человеку</span>
# </a>
# </div>
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="Иллюстративное фото ©Турар Казангапов" src="/userdata/news/2020/news_391473/thumb_xms/photo_308393.jpeg"/>
# </div>
# <span class="tn-article-title">Штраф в 4,5 миллиона тенге выплатит сотрудник акимата СКО</span>
# <ul class="tn-data-list">
# <li>
# <span>вчера, 14:54</span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391473'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>4</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/crime/shtraf-v-45-milliona-tenge-vyiplatit-sotrudnik-akimata-sko-391473/">
# <span class="tn-hidden">Штраф в 4,5 миллиона тенге выплатит сотрудник акимата СКО</span>
# </a>
# </div>
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="© Facebook/uakomar" src="/userdata/news/2020/news_391520/thumb_xms/photo_308447.jpeg"/>
# </div>
# <span class="tn-article-title">"На его месте я подал бы в отставку". Доктор Комаровский высказал претензии Зеленскому</span>
# <ul class="tn-data-list">
# <li>
# <span>вчера, 22:07</span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391520'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>9</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/world_news/na-meste-podal-v-otstavku-doktor-komarovskiy-vyiskazal-391520/">
# <span class="tn-hidden">"На его месте я подал бы в отставку". Доктор Комаровский высказал претензии Зеленскому</span>
# </a>
# </div>
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="Иллюстративное фото: pixabay.com" src="/userdata/news/2020/news_391209/thumb_xms/photo_308087.jpeg"/>
# </div>
# <span class="tn-article-title">Лекарства подорожали в Казахстане</span>
# <ul class="tn-data-list">
# <li>
# <span>11 февраля 2020, 13:49</span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391209'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>24</span></span>
# </li>
# </ul>
# <a class="tn-link" href="/private_finance/lekarstva-podorojali-v-kazahstane-391209/">
# <span class="tn-hidden">Лекарства подорожали в Казахстане</span>
# </a>
# </div>
# </div>
# </section> <section class="tn-mix-section tn-container">
# <div class="tn-section-header">
# <a class="tn-section-title" href="https://mix.tn.kz/" target="_blank">TengriMIX</a>
# <ul class="tn-tag-list">
# <li><a href="/tag/Фотографии">Фотографии</a></li>
# </ul>
# </div>
# <div class="tn-article-grid">
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="Амир Дадорходжаев в образе Джокера. © Фото из личного архива Амира Дадорходжаева " src="/userdata/news/2020/news_391288/thumb_xms/photo_308427.jpeg"/>
# </div>
# <span class="tn-article-title">"Зажгу в Нью-Йорке". Казахстанец стал финалистом престижного балетного конкурса</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>вчера, 18:56</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391288'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>12</span></span>
# </li>
# </ul>
# <a class="tn-link" href="https://mix.tn.kz/mixnews/zajgu-nyu-yorke-kazahstanets-stal-finalistom-prestijnogo-391288/"><span class="tn-hidden">"Зажгу в Нью-Йорке". Казахстанец стал финалистом престижного балетного конкурса</span></a>
# </div>
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt="© pixabay" src="/userdata/news/2020/news_391424/thumb_xms/photo_308347.jpeg"/>
# </div>
# <span class="tn-article-title">Ученые выявили необычное поведение коронавируса в Таиланде</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>вчера, 11:44</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391424'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>7</span></span>
# </li>
# </ul>
# <a class="tn-link" href="https://mix.tn.kz/mixnews/uchenyie-vyiyavili-neobyichnoe-povedenie-koronavirusa-391424/"><span class="tn-hidden">Ученые выявили необычное поведение коронавируса в Таиланде</span></a>
# </div>
# <div class="tn-article-item">
# <div class="tn-image-container">
# <img alt='Фрагмент картины "Портрет юного Абая", А.Кастеев' src="/userdata/news/2020/news_391236/thumb_xms/photo_308216.jpeg"/>
# </div>
# <span class="tn-article-title">10 произведений литературы и искусства, повлиявшие на образ Абая Кунанбаева</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>12 февраля 2020, 13:32</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'391236'" :lang="'ru'" :type="'news'"></view-show-component>
# </li>
# <li>
# <span><i class="tn-icon-comment-dark"></i><span>4</span></span>
# </li>
# </ul>
# <a class="tn-link" href="https://mix.tn.kz/mixnews/10-proizvedeniy-literaturyi-iskusstva-povliyavshie-obraz-391236/"><span class="tn-hidden">10 произведений литературы и искусства, повлиявшие на образ Абая Кунанбаева</span></a>
# </div>
# <div class="tn-article-item">
# <div class="tn-left-240x700-banner"></div>
# </div>
# </div>
# </section>
# <section class="tn-take-a-look-section tn-container">
# <div class="tn-section-header">
# <a class="tn-section-title" href="/take-look/">Посмотри</a>
# <ul class="tn-tag-list">
# <li><a href="/video/">Видео</a></li>
# <li><a href="/fotoarchive/">Фото</a></li>
# <li><a href="/tag/%D0%94%D0%A2%D0%9F/">ДТП</a></li>
# <li><a href="/show/">Шоубизнес</a></li>
# <li><a href="/cinema/">Кино</a></li>
# <li><a href="/tag/life">Жизнь</a></li>
# <li><a href="/tag/Яблоки">Яблоки</a></li>
# </ul>
# </div>
# <div class="tn-article-grid">
# <div class="tn-article-item tn-three-column">
# <div class="tn-image-container">
# <img alt="Смог, снег и школы. Отчетная встреча акима Нур-Султана Алтая Кульгинова" src="/tv/userdata/blogs/blogs_8680/thumb_b/image.jpg"/>
# </div>
# <span class="tn-play-button"><i class="tn-icon-play"></i></span>
# <span class="tn-article-title">Смог, снег и школы. Отчетная встреча акима Нур-Султана Алтая Кульгинова</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>12 февраля 2020, 20:44</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'8680'" :lang="'ru'" :type="'tvblog'"></view-show-component>
# </li>
# </ul>
# <a class="tn-link" href="/tv/novosti/obschestvo/8680/"><span class="tn-hidden">Смог, снег и школы. Отчетная встреча акима Нур-Султана Алтая Кульгинова</span></a>
# </div>
# <div class="tn-article-item">
# <img alt="Детские пособия в Казахстане и России. Сравниваем" src="/tv/userdata/blogs/blogs_8679/thumb_b/image.jpg"/>
# <span class="tn-play-button"><i class="tn-icon-play"></i></span>
# <span class="tn-article-title">Детские пособия в Казахстане и России. Сравниваем</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>12 февраля 2020, 15:39</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'8679'" :lang="'ru'" :type="'tvblog'"></view-show-component>
# </li>
# <li>
# <span>
# <i class="tn-icon-comment-dark"></i><span>0</span>
# </span>
# </li>
# </ul>
# <a class="tn-link" href="/tv/novosti/obschestvo/8679/"><span class="tn-hidden">Детские пособия в Казахстане и России. Сравниваем</span></a>
# </div>
# <div class="tn-article-item">
# <img alt="Нұрсұлтан Назарбаев Қордайда болған қақтығыс туралы" src="/tv/userdata/blogs/blogs_8678/thumb_b/image.jpg"/>
# <span class="tn-play-button"><i class="tn-icon-play"></i></span>
# <span class="tn-article-title">Нұрсұлтан Назарбаев Қордайда болған қақтығыс туралы</span>
# <ul class="tn-data-list">
# <li>
# <span>
# <time>11 февраля 2020, 22:42</time>
# </span>
# </li>
# <li>
# <view-show-component :dark="true" :id="'8678'" :lang="'ru'" :type="'tvblog'"></view-show-component>
# </li>
# <li>
# <span>
# <i class="tn-icon-comment-dark"></i><span>0</span>
# </span>
# </li>
# </ul>
# <a class="tn-link" href="/tv/novosti/politika/8678/"><span class="tn-hidden">Нұрсұлтан Назарбаев Қордайда болған қақтығыс туралы</span></a>
# </div>
# <div class="tn-article-item tn-visible@m">
# <div class="tn-main-banner"></div>
# </div>
# </div>
# </section>
# <div class="tn-container">
# <div class="tn-bottom-banner"></div>
# </div>
# </main>
# <footer>
# <div class="tn-container">
# <div class="tn-footer-grid">
# <div>
# <ul class="tn-data-list">
# <li><a href="/page/about/">О проекте</a></li>
# <li><a href="/page/jobs/">Вакансии</a></li>
# <li><a href="https://docs.google.com/spreadsheets/d/1_CpKYOQMT8SGn9SKQfABEK7dScDoPc5JhfO0GvRD7mw/edit?usp=sharing" target="_blank">Реклама</a></li>
# <li><a href="/press_releases/">Пресс-релизы</a></li>
# <li><a href="/sitemap/">Карта сайта</a></li>
# </ul>
# <a class="tn-copyright-warning" href="/page/information/">Информация об ограничениях использования материалов Tengrinews.kz</a>
# </div>
# <label class="tn-them-layout tn-visible@t" for="tn-theme">Тема:
#                 <div class="onoffswitch">
# <input class="onoffswitch-checkbox" id="tn-theme" name="tn-theme" tn-switch-them="" type="checkbox"/>
# <label class="onoffswitch-label" for="tn-theme"></label>
# </div>
# </label>
# <div>
# <ul class="tn-contact-list">
# <li>Контакты</li>
# <li><a href="tel:+7(727)3888138">+7 (727) 3888 138</a></li>
# <li><a href="tel:+7(717)2542710">+7 (717) 254 2710</a></li>
# </ul>
# </div>
# <div>
# <div class="tn-social-title">Мы в соц. сетях:</div>
# <ul class="tn-social-list">
# <li><a href="https://vk.com/tengrinews" target="_blank"><span class="tn-icon-vk"></span></a></li>
# <li><a href="https://www.facebook.com/Tengrinews.kz/" target="_blank"><i class="tn-icon-fb"></i></a>
# </li>
# <li><a href="https://twitter.com/tengrinewskz" target="_blank"><i class="tn-icon-tw"></i></a></li>
# <li><a href="https://www.instagram.com/tengrinewskz/" target="_blank"><i class="tn-icon-instagram"></i></a></li>
# <li><a href="https://ok.ru/tengrinews.kz" target="_blank"><i class="tn-icon-ok"></i></a></li>
# <li><a href="https://telegram.me/tengrinews" target="_blank"><i class="tn-icon-tg"></i></a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <div class="tn-footer-grid-meta">
# <span class="tn-copyright">© 2008-2020 ТОО «EML»</span>
# <ul class="tn-list-app">
# <li>Приложения Tengrinews для:</li>
# <li><a href="https://itunes.apple.com/kz/app/tengrinews-for-iphone/id510927516?mt=8">iPhone</a></li>
# <li><a href="https://itunes.apple.com/kz/app/tengrinews-for-ipad/id520370213?mt=8">iPad</a></li>
# <li><a href="https://play.google.com/store/apps/details?id=kz.tengrinews">Android</a></li>
# </ul>
# <span class="tn-designer">Designed by <b>ibec
#                     systems</b></span>
# </div>
# </div>
# </footer>
# </div>
# <div class="tn-line-banner"></div>
# <div class="tn-branding-banner"></div>
# <div class="tn-fullscreen-banner"></div>
# <div class="tn-scroll-top">
# <svg data-svg="chevron-up" height="40" viewbox="0 0 20 20" width="40" xmlns="http://www.w3.org/2000/svg">
# <polyline fill="none" points="4 13 10 7 16 13" stroke="#000" stroke-width="1.03"></polyline>
# </svg>
# </div>
# </body>
# <script crossorigin="anonymous" defer="defer" src="/js/loader.js?v=167"></script>
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
#         (function (m, e, t, r, i, k, a) {
#             m[i] = m[i] || function () {
#                 (m[i].a = m[i].a || []).push(arguments)
#             };
#             m[i].l = 1 * new Date();
#             k = e.createElement(t), a = e.getElementsByTagName(t)[0], k.async = 1, k.src = r, a.parentNode.insertBefore(k, a)
#         })
#         (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#         ym(1838272, "init", {
#             clickmap: true,
#             trackLinks: true,
#             accurateTrackBounce: true,
#             webvisor: true
#         });
#     </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/1838272" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <!--LiveInternet counter-->
# <script type="text/javascript">
#         document.write('<a href="//www.liveinternet.ru/click" ' +
#             'target="_blank"><img src="//counter.yadro.ru/hit?t20.1;r' +
#             escape(document.referrer) + ((typeof (screen) == 'undefined') ? '' :
#                 ';s' + screen.width + '*' + screen.height + '*' + (screen.colorDepth ?
#                 screen.colorDepth : screen.pixelDepth)) + ';u' + escape(document.URL) +
#             ';h' + escape(document.title.substring(0, 150)) + ';' + Math.random() +
#             '" alt="" title="LiveInternet: показано число просмотров за 24' +
#             ' часа, посетителей за 24 часа и за сегодня" ' +
#             'border="0" width="88" style="display: none;" height="31"><\/a>')
#     </script><!--/LiveInternet-->
# <!-- /Yandex.Metrika counter -->
# <script async="" src="https://cdn.onthe.io/io.js/TcEIpwNbo0qG"></script>
# <script defer="defer" src="/js/core.js?v=167"></script>
# <script async="async" src="/js/analytic.js"></script>
# <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#         var OneSignal = window.OneSignal || [];
#         OneSignal.push(["init", {
#             appId: "5e0ed479-25e3-4997-9f5c-8786db92b448",
#             autoRegister:  false ,
#             notifyButton: {
#                 enable:  true , /* Required to use the notify button */
#                 size:  "medium" , /* One of 'small', 'medium', or 'large' */
# //                theme     : 'default' , /* One of 'default' (red-white) or 'inverse" (white-red) */
#                 position: 'bottom-left', /* Either 'bottom-left' or 'bottom-right' */
#                 offset: {
#                     bottom:  "20px" ,
# //                    left  : '0px' , /* Only applied if bottom-left */
# //                    right : '0px' /* Only applied if bottom-right */
#                 },
# //                prenotify : true , /* Show an icon with 1 unread message for first-time site visitors */
#                 showCredit: false, /* Hide the OneSignal logo */
#                 text: {
#                     'tip.state.unsubscribed': 'Уведомления от Tengrinews.kz',
#                     'tip.state.subscribed': "Вы подписаны на уведомления",
#                     'tip.state.blocked': "Вы заблокировали оповещения",
#                     'message.prenotify': 'Нажмите, чтобы подписаться на уведомления',
#                     'message.action.subscribed': "Благодарим за подписку!",
#                     'message.action.resubscribed': "Вы подписаны на уведомления",
#                     'message.action.unsubscribed': "Вы больше не будете получать уведомления",
#                     'dialog.main.title': 'Управление уведомлениями на сайте',
#                     'dialog.main.button.subscribe': 'ПОДПИСАТЬСЯ',
#                     'dialog.main.button.unsubscribe': 'ОТПИСАТЬСЯ',
#                     'dialog.blocked.title': 'Разблокировать уведомления',
#                     'dialog.blocked.message': "Следуйте этим инструкциям, чтобы разрешить уведомления:"
#                 },
#                 test: (function () {
#                     var timer;
#                     window.addEventListener('load', function () {
#                         var contentEdit = function () {
#                             if (document.querySelector('.onesignal-bell-launcher-button')) {
#                                 clearInterval(timer);
#                                 var div = document.createElement('div');
#                                 div.classList.add('background');
#                                 div.innerHTML = '<svg version="1.1" class="onesignal-bell-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" width="99.7px" height="99.7px" viewBox="0 0 99.7 99.7" style="filter: drop-shadow(0 2px 4px rgba(34,36,38,0.35));; -webkit-filter: drop-shadow(0 2px 4px rgba(34,36,38,0.35));;" xml:space="preserve">' +
#                                     '<g><circle class="background" cx="49.9" cy="49.9" r="49.9"></circle>' +
#                                     '<g id="Layer_2"><g><path class="foreground" style="fill:#109d01;" d="m 25.5,40.5 0,-12.228572 23.885997,0.1 25.114,0.07857 0,12.050002 -17.114,0 0,5.370926 0,2 0,2.099574 -15.999998,-9.321 0,-0.1495 z"></path>' +
#                                     '<path class="foreground" style="fill:#109d01;" d="m 41.5,60.5 15.999998,9.318 -15.999998,0 z"></path>' +
#                                     '<ellipse style="fill:transparent;" class="stroke" stroke="#fff" cx="50" cy="50" rx="38" ry="38"></ellipse></g></g></g></svg>';
#
#                                 document.querySelector('.onesignal-bell-launcher-button').innerHTML = '';
#                                 document.querySelector('.onesignal-bell-launcher-button').appendChild(div);
#                             }
#                         };
#                         timer = setInterval(contentEdit, 500);
#                     });
#                 })()
#             },
#             promptOptions: {
#                 actionMessage: "Вы хотели бы получать уведомления о последних новостях и событиях.",
#                 acceptButtonText: "ДА!!!",
#                 cancelButtonText: "НЕТ СПАСИБО"
#             }
#         }]);
#     </script>
# </html>
#
# <!DOCTYPE html>
# <html lang="ru">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="pGq9z9GbzuR8y7p9U8vMCm8Cs4RxB1K1QKfUxCjV" name="csrf-token"/>
# <link href="/img/search-tn.png" rel="shortcut icon" type="image/png"/>
# <title>Tengrinews.kz – главный новостной портал Казахстана</title>
# ...
# {'никогда', 'так', 'бы', 'есть', 'ни', 'но', 'или', 'ты', 'об', 'более', 'уж', 'даже', 'им', 'нас', 'под', 'том', 'тут', 'и', 'через', 'себе', 'за', 'того', 'все', 'была', 'если', 'ну', 'был', 'хоть', 'всего', 'эти', 'да', 'ли', 'будет', 'тебя', 'раз', 'зачем', 'ее', 'чем', 'потом', 'из', 'только', 'они', 'он', 'то', 'ним', 'тем', 'на', 'куда', 'над', 'может', 'про', 'по', 'между', 'я', 'нельзя', 'его', 'не', 'совсем', 'три', 'этой', 'тоже', 'моя', 'с', 'во', 'хорошо', 'там', 'больше', 'вы', 'впрочем', 'к', 'после', 'для', 'иногда', 'что', 'перед', 'когда', 'разве', 'где', 'какой', 'вас', 'мы', 'она', 'ей', 'без', 'эту', 'ничего', 'при', 'у', 'два', 'сейчас', 'вам', 'опять', 'ней', 'ведь', 'чтобы', 'этот', 'их', 'ему', 'мой', 'него', 'них', 'такой', 'можно', 'чуть', 'уже', 'о', 'меня', 'почти', 'потому', 'со', 'а', 'лучше', 'как', 'же', 'нее', 'ж', 'здесь', 'этого', 'всю', 'себя', 'тот', 'этом', 'сам', 'было', 'кто', 'будто', 'быть', 'надо', 'свою', 'всегда', 'еще', 'вдруг', 'тогда', 'от', 'до', 'другой', 'вот', 'в', 'какая', 'много', 'конечно', 'теперь', 'один', 'чего', 'мне', 'нибудь', 'чтоб', 'всех', 'нет', 'наконец', 'были'}
# ['Tengrinews.kz', '–', 'главный', 'новостной', 'портал', 'КазахстанаnTengriMixnTengriTVnTengriTravelnПобедителиnЗаконы', 'КазахстанаnКурс', 'валютn376.4n409.56n5.91nУзнайnПочитайnПосмотриnҚазақшаnПРИСЫЛАЙТЕ', 'СВОИ', 'НОВОСТИ', 'НАМnWhatsApp', '+7', '(', '777', ')', '001', '44', '99nИскатьnСрочная', 'новостьnПровал', 'дороги', 'у', 'Сайрана', 'в', 'Алматы', ':', 'причину', 'назовет', 'экспертизаnПосмотретьnУзнайnПочитайnПосмотриnҚазақшаnСпецпроектыnTengriMixnTengriTVnTengriTravelnПобедителиnЗаконы', 'КазахстанаnПрогноз', 'погодыnКурс', 'валютn376.4n409.56n5.91nҚазақшаnПРИСЫЛАЙТЕ', 'СВОИ', 'НОВОСТИ', 'НАМnWhatsApp', '+7', '(', '777', ')', '001', '44', '99nTengrinews.kz', '–', 'главный', 'новостной', 'портал', 'КазахстанаnКазахстанцы', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnвчера', ',', '16:21n74nКазахстанцы', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnАртисты', 'театра', 'Ауэзова', 'отказываются', 'выходить', 'на', 'сценуnсегодня', ',', '01:04n2nКазахстанцы', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnКоронавирус', 'может', 'поразить', '60', 'процентов', 'населения', 'Землиnвчера', ',', '21:35n51nКазахстанцы', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnДаурен', 'Абаев', 'прокомментировал', 'посты', 'Айсултана', 'Рахатаnвчера', ',', '21:03n51nКазахстанцы', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnТри', 'массовых', 'ДТП', 'произошло', 'на', 'трассах', 'в', 'Казахстанеnвчера', ',', '19:09n13nКазахстанцы', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnТокаев', 'потребовал', 'жестко', 'пресекать', 'провокацииnвчера', ',', '18:56n35nКазахстанцы', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnДело', 'о', 'смерти', 'сына', 'Кудебаева', ':', 'адвокат', 'врача', 'пожаловался', 'на', 'затягивание', 'расследованияnвчера', ',', '18:20n19nКазахстанцы', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnПочитайnИнтервьюnСтатьиnБлоги', 'и', 'мненияnТехнологииnНаукаnМавританияnмогулnО', 'первой', 'женщине', 'страныn12', 'февраля', '2020', ',', '14:20n8nО', 'первой', 'женщине', 'страныn', "''", 'Государство', 'никогда', 'так', 'не', 'беспокоилось', 'о', 'моем', 'здоровье', ',', 'как', 'после', 'возвращения', 'из', 'Китая', "''", 'n11', 'февраля', '2020', ',', '14:25n9n', "''", 'Государство', 'никогда', 'так', 'не', 'беспокоилось', 'о', 'моем', 'здоровье', ',', 'как', 'после', 'возвращения', 'из', 'Китая', "''", 'nПро', 'Кордай', 'и', 'все', ',', 'что', 'с', 'ним', 'связаноn10', 'февраля', '2020', ',', '12:05n80nПро', 'Кордай', 'и', 'все', ',', 'что', 'с', 'ним', 'связаноnКаких', 'животных', 'казахи', 'не', 'использовали', 'в', 'хозяйстве', '.', 'Об', 'обычае', 'бәсіреn07', 'февраля', '2020', ',', '15:34n9nКаких', 'животных', 'казахи', 'не', 'использовали', 'в', 'хозяйстве', '.', 'Об', 'обычае', 'бәсіреnУзнайnНовости', 'КазахстанаnНовости', 'МираnПроишествияnСпортnДобычаnреабилитацияn', "''", 'Вези', ',', 'тварь', '!', 'Люди', 'ждут', "''", '.', 'Пассажирка', 'устроила', 'истерику', 'в', 'таксиnвчера', ',', '20:46n49n', "''", 'Вези', ',', 'тварь', '!', 'Люди', 'ждут', "''", '.', 'Пассажирка', 'устроила', 'истерику', 'в', 'таксиnМассовую', 'потасовку', 'затеяли', 'футболисты', '``', 'Кайрата', "''", 'и', '``', 'Динамо', "''", 'nвчера', ',', '23:32n6nМассовую', 'потасовку', 'затеяли', 'футболисты', '``', 'Кайрата', "''", 'и', '``', 'Динамо', "''", 'nБоярский', 'отказался', 'комментировать', 'нарушение', ':', '``', 'Как', 'вы', 'все', 'надоели', "''", 'nвчера', ',', '22:59n14nБоярский', 'отказался', 'комментировать', 'нарушение', ':', '``', 'Как', 'вы', 'все', 'надоели', "''", 'nНовый', 'vivo', 'V17', 'поможет', 'принести', 'радость', 'любимому', 'человекуn10', 'февраля', '2020', ',', '09 ...
# ['главный', 'новостной', 'портал', 'казахстанаntengrimixntengritvntengritravelnпобедителиnзаконы', 'казахстанаnкурс', 'свои', 'новости', 'намnwhatsapp', 'новостьnпровал', 'дороги', 'у', 'сайрана', 'в', 'алматы', 'причину', 'назовет', 'экспертизаnпосмотретьnузнайnпочитайnпосмотриnқазақшаnспецпроектыntengrimixntengritvntengritravelnпобедителиnзаконы', 'казахстанаnпрогноз', 'погодыnкурс', 'свои', 'новости', 'намnwhatsapp', 'главный', 'новостной', 'портал', 'казахстанаnказахстанцы', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnвчера', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnартисты', 'театра', 'ауэзова', 'отказываются', 'выходить', 'на', 'сценуnсегодня', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnкоронавирус', 'может', 'поразить', 'процентов', 'населения', 'землиnвчера', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnдаурен', 'абаев', 'прокомментировал', 'посты', 'айсултана', 'рахатаnвчера', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnтри', 'массовых', 'дтп', 'произошло', 'на', 'трассах', 'в', 'казахстанеnвчера', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnтокаев', 'потребовал', 'жестко', 'пресекать', 'провокацииnвчера', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnдело', 'о', 'смерти', 'сына', 'кудебаева', 'адвокат', 'врача', 'пожаловался', 'на', 'затягивание', 'расследованияnвчера', 'оказались', 'запертыми', 'с', 'зараженными', 'коронавирусом', 'на', 'круизном', 'лайнереnпочитайnинтервьюnстатьиnблоги', 'и', 'мненияnтехнологииnнаукаnмавританияnмогулnо', 'первой', 'женщине', 'февраля', 'первой', 'женщине', 'страныn', 'государство', 'никогда', 'так', 'не', 'беспокоилось', 'о', 'моем', 'здоровье', 'как', 'после', 'возвращения', 'из', 'китая', 'февраля', 'государство', 'никогда', 'так', 'не', 'беспокоилось', 'о', 'моем', 'здоровье', 'как', 'после', 'возвращения', 'из', 'китая', 'nпро', 'кордай', 'и', 'все', 'что', 'с', 'ним', 'февраля', 'кордай', 'и', 'все', 'что', 'с', 'ним', 'связаноnкаких', 'животных', 'казахи', 'не', 'использовали', 'в', 'хозяйстве', 'об', 'обычае', 'февраля', 'животных', 'казахи', 'не', 'использовали', 'в', 'хозяйстве', 'об', 'обычае', 'бәсіреnузнайnновости', 'казахстанаnновости', 'мираnпроишествияnспортnдобычаnреабилитацияn', 'вези', 'тварь', 'люди', 'ждут', 'пассажирка', 'устроила', 'истерику', 'в', 'таксиnвчера', 'вези', 'тварь', 'люди', 'ждут', 'пассажирка', 'устроила', 'истерику', 'в', 'таксиnмассовую', 'потасовку', 'затеяли', 'футболисты', 'кайрата', 'и', 'динамо', 'nвчера', 'потасовку', 'затеяли', 'футболисты', 'кайрата', 'и', 'динамо', 'nбоярский', 'отказался', 'комментировать', 'нарушение', 'как', 'вы', 'все', 'надоели', 'nвчера', 'отказался', 'комментировать', 'нарушение', 'как', 'вы', 'все', 'надоели', 'nновый', 'vivo', 'поможет', 'принести', 'радость', 'любимому', 'февраля', 'vivo', 'поможет', 'принести', 'радость', 'любимому', 'человекуnштраф', 'в', 'миллиона', 'тенге', 'выплатит', 'сотрудник', 'акимата', 'скоnвчера', 'в', 'миллиона', 'тенге', 'выплатит', 'сотрудник', 'акимата', 'скоn', 'на', 'его', 'месте', 'я', 'подал', 'бы', 'в', 'отставку', 'доктор', 'комаровский', 'высказал', 'претензии', 'зеленскомуnвчера', 'на', 'его', 'месте', 'я', 'подал', 'бы', 'в', 'отставку', 'доктор', 'комаровский', 'высказал', 'претензии', 'зеленскомуnлекарства', 'подорожали', 'в', 'февраля', 'подорожали', 'в', 'казахстанеntengrimixnфотографииn', 'зажгу', 'в', 'казахстанец', 'стал', 'финалистом', 'престижного', 'балетного', 'конкурсаnвчера', 'зажгу', 'в', 'казахстанец', 'стал', 'финалистом', 'престижного', 'балетного', 'конкурсаnученые', 'выявили', 'необычное', 'поведение', 'коронавируса', 'в', 'таиландеnвчера', 'выявили', 'необычное', 'поведение', 'коронавируса', 'в', 'произведений', 'литературы', 'и', ...
# ['главный', 'новостной', 'портал', 'казахстанаntengrimixntengritvntengritravelnпобедителиnзаконы', 'казахстанаnкурс', 'свои', 'новости', 'намnwhatsapp', 'новостьnпровал', 'дороги', 'сайрана', 'алматы', 'причину', 'назовет', 'экспертизаnпосмотретьnузнайnпочитайnпосмотриnқазақшаnспецпроектыntengrimixntengritvntengritravelnпобедителиnзаконы', 'казахстанаnпрогноз', 'погодыnкурс', 'свои', 'новости', 'намnwhatsapp', 'главный', 'новостной', 'портал', 'казахстанаnказахстанцы', 'оказались', 'запертыми', 'зараженными', 'коронавирусом', 'круизном', 'лайнереnвчера', 'оказались', 'запертыми', 'зараженными', 'коронавирусом', 'круизном', 'лайнереnартисты', 'театра', 'ауэзова', 'отказываются', 'выходить', 'сценуnсегодня', 'оказались', 'запертыми', 'зараженными', 'коронавирусом', 'круизном', 'лайнереnкоронавирус', 'поразить', 'процентов', 'населения', 'землиnвчера', 'оказались', 'запертыми', 'зараженными', 'коронавирусом', 'круизном', 'лайнереnдаурен', 'абаев', 'прокомментировал', 'посты', 'айсултана', 'рахатаnвчера', 'оказались', 'запертыми', 'зараженными', 'коронавирусом', 'круизном', 'лайнереnтри', 'массовых', 'дтп', 'произошло', 'трассах', 'казахстанеnвчера', 'оказались', 'запертыми', 'зараженными', 'коронавирусом', 'круизном', 'лайнереnтокаев', 'потребовал', 'жестко', 'пресекать', 'провокацииnвчера', 'оказались', 'запертыми', 'зараженными', 'коронавирусом', 'круизном', 'лайнереnдело', 'смерти', 'сына', 'кудебаева', 'адвокат', 'врача', 'пожаловался', 'затягивание', 'расследованияnвчера', 'оказались', 'запертыми', 'зараженными', 'коронавирусом', 'круизном', 'лайнереnпочитайnинтервьюnстатьиnблоги', 'мненияnтехнологииnнаукаnмавританияnмогулnо', 'первой', 'женщине', 'февраля', 'первой', 'женщине', 'страныn', 'государство', 'беспокоилось', 'моем', 'здоровье', 'возвращения', 'китая', 'февраля', 'государство', 'беспокоилось', 'моем', 'здоровье', 'возвращения', 'китая', 'nпро', 'кордай', 'февраля', 'кордай', 'связаноnкаких', 'животных', 'казахи', 'использовали', 'хозяйстве', 'обычае', 'февраля', 'животных', 'казахи', 'использовали', 'хозяйстве', 'обычае', 'бәсіреnузнайnновости', 'казахстанаnновости', 'мираnпроишествияnспортnдобычаnреабилитацияn', 'вези', 'тварь', 'люди', 'ждут', 'пассажирка', 'устроила', 'истерику', 'таксиnвчера', 'вези', 'тварь', 'люди', 'ждут', 'пассажирка', 'устроила', 'истерику', 'таксиnмассовую', 'потасовку', 'затеяли', 'футболисты', 'кайрата', 'динамо', 'nвчера', 'потасовку', 'затеяли', 'футболисты', 'кайрата', 'динамо', 'nбоярский', 'отказался', 'комментировать', 'нарушение', 'надоели', 'nвчера', 'отказался', 'комментировать', 'нарушение', 'надоели', 'nновый', 'vivo', 'поможет', 'принести', 'радость', 'любимому', 'февраля', 'vivo', 'поможет', 'принести', 'радость', 'любимому', 'человекуnштраф', 'миллиона', 'тенге', 'выплатит', 'сотрудник', 'акимата', 'скоnвчера', 'миллиона', 'тенге', 'выплатит', 'сотрудник', 'акимата', 'скоn', 'месте', 'подал', 'отставку', 'доктор', 'комаровский', 'высказал', 'претензии', 'зеленскомуnвчера', 'месте', 'подал', 'отставку', 'доктор', 'комаровский', 'высказал', 'претензии', 'зеленскомуnлекарства', 'подорожали', 'февраля', 'подорожали', 'казахстанеntengrimixnфотографииn', 'зажгу', 'казахстанец', 'стал', 'финалистом', 'престижного', 'балетного', 'конкурсаnвчера', 'зажгу', 'казахстанец', 'стал', 'финалистом', 'престижного', 'балетного', 'конкурсаnученые', 'выявили', 'необычное', 'поведение', 'коронавируса', 'таиландеnвчера', 'выявили', 'необычное', 'поведение', 'коронавируса', 'произведений', 'литературы', 'искусства', 'повлиявшие', 'образ', 'абая', 'февраля', 'произведений', 'литературы', 'искусства', 'повлиявшие', 'образ', 'абая', 'кунанбаеваnпосмотриnвидеоnфотоnдтпnшоубизнесnкиноnжизньnяблокиnсмог', 'снег', 'школы', 'отчетная', 'встреча', 'акима', 'алтая', 'февраля', 'снег', 'школы', 'отчетная', 'встреча', 'акима', 'алтая', 'кульгиноваnдетские', 'пособия', 'казахстане', 'россии', 'февраля', 'пособия', 'казахстане', 'россии', 'сравниваемnнұрсұлтан', 'назарбаев', 'қордайда', 'болған', 'қақтығыс', ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wc = WordCloud(max_words=1000, margin=10, background_color='white',
scale=3, relative_scaling = 0.5, width=500, height=400,
random_state=1).generate(' '.join(filtered_words))
plt.figure(figsize=(20,10))
plt.imshow(wc)
plt.axis("off")
plt.show()
#wc.to_file("/wordcloud.png")
